# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\User\Desktop\IEP PROJECTS\online_food_delivery_dataset.csv")

# %%
df.head()
# Out:
#   Order_ID  Order_Date       City Restaurant_Name Cuisine_Type  Order_Amount  \
# 0     ORD1  2026-02-22     Mumbai       Spice Hub      Italian        842.90
# 1     ORD2  2026-02-22       Pune   Curry Kingdom       Indian        974.79
# 2     ORD3  2026-02-22  Hyderabad      Sushi Spot      Chinese       1459.93
# 3     ORD4  2026-02-22    Chennai      Sushi Spot      Italian        151.44
# 4     ORD5  2026-02-22      Delhi     Burger Town       Indian        949.10
#
#   Discount_Applied  Discount_Amount  Final_Amount Payment_Method  \
# 0              Yes              0.0        842.90           Card
# 1              Yes             50.0        924.79            UPI
# 2              NaN              0.0       1459.93           Card
# 3              Yes            100.0         51.44           Cash
# 4              Yes              0.0        949.10           Card
#
#    Delivery_Time_Minutes  Distance_km  Rider_Rating  Customer_Rating  \
# ...

# %% [markdown]
# ## Data Exploration

# %%
df.shape
# Out:
# (2000, 15)

# %%
df.dtypes
# Out:
# Order_ID                  object
# Order_Date                object
# City                      object
# Restaurant_Name           object
# Cuisine_Type              object
# Order_Amount             float64
# Discount_Applied          object
# Discount_Amount          float64
# Final_Amount             float64
# Payment_Method            object
# Delivery_Time_Minutes      int64
# Distance_km              float64
# Rider_Rating             float64
# Customer_Rating          float64
# Order_Status              object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order_ID               2000 non-null   object
#  1   Order_Date             2000 non-null   object
#  2   City                   2000 non-null   object
#  3   Restaurant_Name        2000 non-null   object
#  4   Cuisine_Type           2000 non-null   object
#  5   Order_Amount           2000 non-null   float64
#  6   Discount_Applied       1308 non-null   object
#  7   Discount_Amount        1602 non-null   float64
#  8   Final_Amount           2000 non-null   float64
#  9   Payment_Method         2000 non-null   object
#  10  Delivery_Time_Minutes  2000 non-null   int64
#  11  Distance_km            2000 non-null   float64
#  12  Rider_Rating           2000 non-null   float64
#  13  Customer_Rating        2000 non-null   float64
# ...

# %%
df.describe()
# Out:
#        Order_Amount  Discount_Amount  Final_Amount  Delivery_Time_Minutes  \
# count   2000.000000      1602.000000   2000.000000            2000.000000
# mean    1085.763850        73.501873   1026.888850              66.860000
# std      528.008753        55.899071    532.206049              30.612889
# min      150.350000         0.000000     13.000000              15.000000
# 25%      630.217500         0.000000    572.170000              39.000000
# 50%     1092.000000        50.000000   1029.485000              67.000000
# 75%     1542.392500       100.000000   1487.135000              94.000000
# max     1999.160000       150.000000   1999.160000             119.000000
#
#        Distance_km  Rider_Rating  Customer_Rating
# count  2000.000000   2000.000000      2000.000000
# mean     15.840255      3.773350         3.495650
# std       8.490122      0.712277         0.870899
# min       1.000000      2.500000         2.000000
# ...

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Null values

# %%
df.isnull().sum()
# Out:
# Order_ID                   0
# Order_Date                 0
# City                       0
# Restaurant_Name            0
# Cuisine_Type               0
# Order_Amount               0
# Discount_Applied         692
# Discount_Amount          398
# Final_Amount               0
# Payment_Method             0
# Delivery_Time_Minutes      0
# Distance_km                0
# Rider_Rating               0
# Customer_Rating            0
# Order_Status               0
# dtype: int64

# %%
#The null values are less than 50%, so replace it wwith mode[discount applied,discount_amount]

# %%
df["Discount_Applied"] = df["Discount_Applied"].fillna(df["Discount_Applied"].mode()[0])

# %%
df.isnull().sum()
# Out:
# Order_ID                   0
# Order_Date                 0
# City                       0
# Restaurant_Name            0
# Cuisine_Type               0
# Order_Amount               0
# Discount_Applied           0
# Discount_Amount          398
# Final_Amount               0
# Payment_Method             0
# Delivery_Time_Minutes      0
# Distance_km                0
# Rider_Rating               0
# Customer_Rating            0
# Order_Status               0
# dtype: int64

# %%
df["Discount_Amount"].skew()
# Out:
# np.float64(0.03352813227963141)

# %%
df["Discount_Amount"] = df["Discount_Amount"].fillna(df["Discount_Amount"].mean())

# %%
df.isnull().sum()
# Out:
# Order_ID                 0
# Order_Date               0
# City                     0
# Restaurant_Name          0
# Cuisine_Type             0
# Order_Amount             0
# Discount_Applied         0
# Discount_Amount          0
# Final_Amount             0
# Payment_Method           0
# Delivery_Time_Minutes    0
# Distance_km              0
# Rider_Rating             0
# Customer_Rating          0
# Order_Status             0
# dtype: int64

# %% [markdown]
# ### Duplicates

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ## Outlier Analysis

# %% [markdown]
# ### IQR (APPLICABLE TO NUMERICAL DATASET)

# %%
import numpy as np
a = df.select_dtypes(include=np.number)
a
# Out:
#       Order_Amount  Discount_Amount  Final_Amount  Delivery_Time_Minutes  \
# 0           842.90         0.000000        842.90                    107
# 1           974.79        50.000000        924.79                    101
# 2          1459.93         0.000000       1459.93                     36
# 3           151.44       100.000000         51.44                     74
# 4           949.10         0.000000        949.10                     63
# ...            ...              ...           ...                    ...
# 1995        944.25        73.501873        944.25                     45
# 1996       1000.04        73.501873       1000.04                     27
# 1997       1822.37       100.000000       1722.37                    114
# 1998        531.14         0.000000        531.14                     26
# 1999        914.43        50.000000        864.43                     29
#
#       Distance_km  Rider_Rating  Customer_Rating
# ...

# %%
#calcuate Quantile
for i in a:
    q1 = a[i].quantile(0.25)
    q2 = a[i].quantile(0.50)
    q3 = a[i].quantile(0.75)

# %%
IQR = q3-q1

# %%
Uw = q3+1.5*IQR
Lw = q1-1.5*IQR

# %%
outliers = ((a[i]>Uw)|(a[i]<Lw))

# %%
print(outliers.sum())
# Out:
# 0

# %%
##Boxplot

# %%
import seaborn as sns

# %%
sns.boxplot([df["Order_Amount"],df["Discount_Amount"],df["Final_Amount"]])
# Out:
# <Axes: >

# %% [markdown]
# ## Data Analysis

# %%
a = pd.DataFrame(df.groupby("City")["Order_ID"].count().sort_values(ascending=False))
a.to_csv("city_order")

# %%
b = pd.DataFrame(df.groupby("Restaurant_Name")["Order_ID"].count().sort_values(ascending=False))
b.to_csv("restaurant_order")

# %%
c = pd.DataFrame(df.groupby("Restaurant_Name")["Customer_Rating"].mean())
c.to_csv("restaurant_rating") #average rating

# %%
d = pd.DataFrame(df.groupby("Cuisine_Type")["Order_ID"].count().sort_values(ascending=False))
d.to_csv("cuisine_order")

# %%
e = pd.DataFrame(df.groupby("Order_Status")["Order_ID"].count())
e.to_csv("cancel_order")

# %%
f = pd.DataFrame(df.groupby("Payment_Method")["Order_ID"].count())
f.to_csv("payment_order")

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\User\IEP PROJECTS
